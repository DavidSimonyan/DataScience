# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
Movies = pd.read_csv("Section6-Homework-Data.csv", encoding = "latin1")

# %%
Movies.head(4)
Movies.columns = ['DayOfWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGrossMillion', 'BudgetMillion', 'GrossMillion',
       'IMDbRating', 'MovieLensRating', 'OverseasMillion', 'OverseasPercent',
       'ProfitMillion', 'ProfitPercent', 'RuntimeMinute', 'USMillion',
       'GrossPercentUS']

# %%
FilteredMovies = Movies[(Movies.Genre == "action") | \
       (Movies.Genre == "comedy") | \
      (Movies.Genre == "adventure") | \
       (Movies.Genre == "animation") | \
      (Movies.Genre == "drama")][(Movies.Studio == "Buena Vista Studios") | \
                                (Movies.Studio == "Sony") | \
                                (Movies.Studio == "Universal") | \
                                (Movies.Studio == "WB") | \
                                (Movies.Studio == "Fox")]

# %%
sns.set(style = "darkgrid", palette = "muted", color_codes = True)

ax = sns.boxplot(data = FilteredMovies, x = "Genre", y = "GrossPercentUS", color = "lightgray", showfliers = False, fliersize = 5)
plt.setp(ax.artists, alpha = 0.5)

sns.stripplot(data = FilteredMovies, x = "Genre", y = "GrossPercentUS", jitter = True, \
              size = 6, linewidth = 0, hue = "Studio", alpha = 0.7)

ax.axes.set_title("Domestic Gross % by Genre", fontsize = "24")
ax.axes.set_xlabel("Genre", fontsize = "12")
ax.axes.set_ylabel("Gross % US", fontsize = "12")

ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
